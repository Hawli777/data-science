# %%
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "shanghai_china.osm"  # 可根据地区更换osm文件
SAMPLE_FILE = "shanghai4.osm"

k = 70 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
# 查看osm文件的大小
ls -l shanghai4.osm
# Out:
# -rw-r--r--  1 lihan  staff  11131809  8 15 16:26 shanghai4.osm

# %%
# 查看详细文件
less shanghai4.osm

# %%
# 迭代解析处理地图文件，并找出有什么样的标记，以及有多少个，以便了解预计在地图中的每个类别有多少数据
import xml.etree.cElementTree as ET
import pprint
SAMPLE_FILE = "shanghai4.osm"
def count_tags(filename):
    elem_dict = {}
    for _, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag in elem_dict:
            elem_dict[elem.tag] += 1
        else:
            elem_dict[elem.tag] = 1
    return elem_dict

# %%
def test():

    tags = count_tags('shanghai4.osm')
    pprint.pprint(tags)
       

if __name__ == "__main__":
    test()
# Out:
# {'member': 1331,
#  'nd': 60639,
#  'node': 51893,
#  'osm': 1,
#  'relation': 47,
#  'tag': 17990,
#  'way': 6481}

# %%
# 看看未取样前文件的标记及数据
def test():

    tags = count_tags('shanghai_china.osm')
    pprint.pprint(tags)
       

if __name__ == "__main__":
    test()
# Out:
# {'bounds': 1,
#  'member': 56053,
#  'nd': 4298484,
#  'node': 3632460,
#  'osm': 1,
#  'relation': 3330,
#  'tag': 1249009,
#  'way': 453680}

# %%
# 检查每个“<标记>”的“k”值，看看是否存在潜在问题
import re
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        key = element.attrib['k']
        if lower.match(key):
            keys['lower'] +=1
        elif lower_colon.search(key):
            keys['lower_colon'] += 1
        elif problemchars.search(key):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
        pass
        
    return keys

# %%
def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
def test():
    keys = process_map('shanghai4.osm')
    pprint.pprint(keys)
    


if __name__ == "__main__":
    test()
# Out:
# {'lower': 16207, 'lower_colon': 1749, 'other': 34, 'problemchars': 0}

# %%
def test():
    keys = process_map('shanghai_china.osm')
    pprint.pprint(keys)
    


if __name__ == "__main__":
    test()
# Out:
# {'lower': 1126241, 'lower_colon': 120051, 'other': 2715, 'problemchars': 2}

# %%
# 查看为地图做贡献的用户
def get_user(element):
    if 'uid' in element.attrib:
        return element.attrib['uid']
    
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))

    return users


def test():

    users = process_map('shanghai4.osm')
    pprint.pprint(users)



if __name__ == "__main__":
    test()
# Out:
# set(['1001766',
#      '101611',
#      '1016648',
#      '102398',
#      '1045590',
#      '104808',
#      '1051550',
#      '105260',
#      '1056443',
#      '1056611',
#      '1068692',
#      '106914',
#      '1069176',
#      '1073950',
#      '110639',
#      '1114156',
#      '1115268',
#      '1122708',
#      '1123861',
#      '1144604',
#      '11463',
#      '1164',
#      '116515',
#      '1167947',
#      '1179821',
#      '118021',
#      '1185631',
#      '1187510',
#      '1189602',
#      '1190212',
#      '119281',
#      '119348',
#      '1195808',
#      '1200724',
#      '1207628',
#      '121036',
#      '1213049',
#      '121406',
#      '1215325',
#      '1219875',
#      '1227959',
#      '1232293',
#      '1236135',
#      '1238487',
#      '1238664',
#      '1240849',
#      '1245973',
#      '124788',
#      '1260280',
#      '1263561',
#      '1293194',
#      '1294163',
#      '131048',
#      '1311287',
#      '1314388',
#      '131670',
#      '131968',
#      '13203',
#      '13257',
#      '1328943',
#      '136645',
#      '136807',
#      '1370163',
#      '13721',
#      '1380023',
#      '1380953',
#      '1393055',
#      '14002',
#      '141420',
#      '1415875',
#      '1417804',
#      '1418137',
#      '1420318',
#      '1427293',
#      '1436097',
#      '1443767',
#      '145401',
#      '1469704',
#      '1483661',
#      '1487220',
#      '1498621',
#      '1500350',
#      '1502427',
#      '150368',
#      '154757',
#      '155277',
#      '15740',
#      '15908',
#      '1607555',
#      '16319',
#      '1638106',
#      '1644558',
#      '164748',
#      '165',
#      '165869',
#      '166129',
#      '16619',
#      '166235',
#      '1679',
#      '1704117',
#      '1705334',
#      '1705933',
#      '1708958',
#      '1710413',
#      '172061',
#      '1726068',
#      '1731253',
#      '1734395',
#      '1735613',
#      '173623',
#      '1738852',
#      '1743716',
#      '17490',
#      '17497',
#      '1759666',
#      '1772211',
#      '1777286',
#      '1778799',
#      '1778953',
#      '1780757',
#      '1780971',
#      '178186',
#      '1790329',
#      '1790827',
#      '1791764',
#      '1795336',
#      '1798312',
#      '1800797',
#      '1803854',
#      '1804331',
#      '18052',
#      '180541',
#      '1806380',
#      '1806800',
#      '18069',
#      '18106',
#      '181135',
#      '1813711',
#      '181561',
#      '1816511',
#      '1817244',
#      '1819191',
#      '182165',
#      '1825040',
#      '1826060',
#      '1829683',
#      '1833906',
#      '183579',
#      '1836406',
#      '1841996',
#      '1844680',
#      '1849012',
#      '1851374',
#      '1855271',
#      '1859772',
#      '1863966',
#      '1867185',
#      '1868705',
#      '1870508',
#      '1871024',
#      '1872844',
#      '1873274',
#      '1877821',
#      '1880637',
#      '1889317',
#      '1891561',
#      '1892020',
#      '189328',
#      '1901087',
#      '1902055',
#      '1907534',
#      '1911765',
#      '1915680',
#      '1919824',
#      '1923880',
#      '1925351',
#      '193401',
#      '1934711',
#      '1942183',
#      '1948686',
#      '1951158',
#      '1951271',
#      '1951326',
#      '1951659',
#      '195610',
#      '1960708',
#      '1966373',
#      '1966716',
#      '1967344',
#      '1968467',
#      '1970556',
#      '1978817',
#      '1984668',
#      '1987309',
#      '1987359',
#      '1992246',
#      '1995673',
#      '1997038',
#      '2006256',
#      '2006304',
#      '2007796',
#      '201024',
#      '2013615',
#      '2019423',
#      '2034654',
#      '2036923',
#      '204045',
#      '2044007',
#      '2050751',
#      '2057189',
#      '2061091',
#      '2061320',
#      '2069336',
#      '2071063',
#      '2083307',
#      '2084207',
#      '2085058',
#      '2085503',
#      '2085822',
#      '2085910',
#      '2086028',
#      '2088610',
#      '2092738',
#      '2092749',
#      '2100300',
#      '2100550',
#      '2100680',
#      '210173',
#      '2104133',
#      '210430',
#      '2108064',
#      '2109056',
#      '2110104',
#      '21118',
#      '2113287',
#      '2114252',
#      '2120244',
#      '2125554',
#      '212575',
#      '2126692',
#      '2127569',
#      '2135605',
#      '2142064',
#      '214577',
#      '2148110',
#      '2159247',
#      '2159337',
#      '2163975',
#      '2184890',
#      '2186308',
#      '2186723',
#      '2191523',
#      '220682',
#      '2209900',
#      '22108',
#      '2214753',
#      '2214848',
#      '2215592',
#      '2219338',
#      '2219985',
#      '2223971',
#      '2225546',
#      '2226712',
#      '2232599',
#      '2238048',
#      '2238844',
#      '2239961',
#      '2248944',
#      '224918',
#      '2249643',
#      '2251514',
#      '225559',
#      '2258307',
#      '2263439',
#      '2271971',
#      '2275300',
#      '2279682',
#      '22827',
#      '2286161',
#      '2292317',
#      '2305716',
#      '2318',
#      '2329388',
#      '233180',
#      '233376',
#      '233759',
#      '2344498',
#      '2357353',
#      '2361715',
#      '23644',
#      '2369126',
#      '2376526',
#      '2377377',
#      '23785',
#      '237940',
#      '2379735',
#      '2381605',
#      '2385757',
#      '2404376',
#      '2414617',
#      '2423635',
#      '24247',
#      '2431429',
#      '2433219',
#      '2440593',
#      '24440',
#      '2445888',
#      '24942',
#      '2500',
#      '2507347',
#      '2508151',
#      '2511706',
#      '2512300',
#      '2513563',
#      '2518094',
#      '2520879',
#      '2522869',
#      '2522884',
#      '2530118',
#      '253683',
#      '25475',
#      '2551002',
#      '2562372',
#      '2574062',
#      '257555',
#      '2602106',
#      '2607646',
#      '2610427',
#      '26139',
#      '2618832',
#      '2622172',
#      '26299',
#      '2631856',
#      '2639622',
#      '2649006',
#      '2658304',
#      '2665933',
#      '267767',
#      '2704394',
#      '2715470',
#      '2719768',
#      '2728110',
#      '2734343',
#      '2734355',
#      '2734357',
#      '2735361',
#      '2740122',
#      '2743989',
#      '27454',
#      '2748195',
#      '274857',
#      '2757603',
#      '2759372',
#      '2760878',
#      '2780218',
#      '2788553',
#      '2823295',
#      '282922',
#      '2834413',
#      '2845865',
#      '2845965',
#      '2847988',
#      '2855608',
#      '285891',
#      '2859806',
#      '2880181',
#      '288524',
#      '2889758',
#      '2891170',
#      '2899929',
#      '2901737',
#      '2905914',
#      '2907600',
#      '2913188',
#      '2913572',
#      '2921845',
#      '2937899',
#      '2938206',
#      '2943323',
#      '2948558',
#      '2952446',
#      '2963768',
#      '2967086',
#      '29717',
#      '298472',
#      '2992037',
#      '2995980',
#      '2996065',
#      '3004347',
#      '3019495',
#      '3019749',
#      '3020905',
#      '302409',
#      '303079',
#      '3040647',
#      '3043360',
#      '304705',
#      '306409',
#      '306747',
#      '307415',
#      '3091009',
#      '311833',
#      '3118625',
#      '31231',
#      '3124055',
#      '3126748',
#      '313111',
#      '313327',
#      '3136367',
#      '3137659',
#      '3137687',
#      '3139729',
#      '3140303',
#      '314211',
#      '3158',
#      '3164012',
#      '3164736',
#      '316860',
#      '3182193',
#      '3189456',
#      '3191854',
#      '3198900',
#      '3208292',
#      '321042',
#      '3216165',
#      '3241388',
#      '3250154',
#      '3250961',
#      '3264783',
#      '327066',
#      '3287715',
#      '3298268',
#      '3298535',
#      '3304654',
#      '3308004',
#      '3320809',
#      '3323283',
#      '3327036',
#      '3328044',
#      '333194',
#      '3339203',
#      '3354788',
#      '336460',
#      '3374518',
#      '33757',
#      '3385224',
#      '338611',
#      '3392056',
#      '3400070',
#      '3404001',
#      '3414196',
#      '342402',
#      '3424135',
#      '3427758',
#      '3433249',
#      '3437087',
#      '34385',
#      '3450290',
#      '3470947',
#      '347944',
#      '3490410',
#      '3497015',
#      '3497647',
#      '3505798',
#      '3506016',
#      '3508588',
#      '3510066',
#      '3521219',
#      '3526564',
#      '3529290',
#      '352940',
#      '3536929',
#      '355282',
#      '356014',
#      '3571864',
#      '3579630',
#      '3581489',
#      '35949',
#      '360397',
#      '3618297',
#      '3618976',
#      '3619060',
#      '3638054',
#      '3640254',
#      '3640745',
#      '3641541',
#      '3642735',
#      '365274',
#      '365279',
#      '365944',
#      '365951',
#      '3691003',
#      '3691120',
#      '3693002',
#      '3705021',
#      '3714910',
#      '3718368',
#      '37252',
#      '3725439',
#      '3727025',
#      '3731755',
#      '374193',
#      '375116',
#      '3756906',
#      '3765004',
#      '3777659',
#      '3779486',
#      '3786101',
#      '378737',
#      '3789238',
#      '3790564',
#      '379362',
#      '3796119',
#      '3800658',
#      '3804164',
#      '381126',
#      '3823680',
#      '382407',
#      '382514',
#      '383625',
#      '3836466',
#      '3839010',
#      '3840641',
#      '384084',
#      '385027',
#      '3855047',
#      '38553',
#      '386131',
#      '3876243',
#      '3882630',
#      '3882811',
#      '3883999',
#      '388809',
#      '3891506',
#      '3912217',
#      '3917456',
#      '3924694',
#      '39826',
#      '3996514',
#      '401161',
#      '4032506',
#      '4035796',
#      '4035994',
#      '4040327',
#      '40481',
#      '4071920',
#      '4071923',
#      '4071947',
#      '4072122',
#      '4084401',
#      '40857',
#      '409326',
#      '411298',
#      '4117304',
#      '413914',
#      '4148925',
#      '4159619',
#      '416346',
#      '4172387',
#      '4206228',
#      '4210803',
#      '421504',
#      '421932',
#      '4236594',
#      '42429',
#      '4247318',
#      '42537',
#      '42546',
#      '4272580',
#      '4289312',
#      '4293887',
#      '4325719',
#      '4329713',
#      '4331397',
#      '4349815',
#      '4354779',
#      '4355902',
#      '4361066',
#      '4363',
#      '436419',
#      '4364275',
#      '437598',
#      '4382050',
#      '43906',
#      '4391234',
#      '4396547',
#      '442153',
#      '4427307',
#      '4431885',
#      '4448511',
#      '445671',
#      '445705',
#      '445743',
#      '4459720',
#      '44759',
#      '4477518',
#      '449630',
#      '4497723',
#      '450333',
#      '4541666',
#      '454589',
#      '456610',
#      '4592',
#      '45952',
#      '4597094',
#      '4609478',
#      '4609991',
#      '4614583',
#      '46497',
#      '4651232',
#      '4663062',
#      '467213',
#      '4673612',
#      '4687693',
#      '4688437',
#      '4701851',
#      '4731522',
#      '4745676',
#      '475557',
#      '4758931',
#      '475943',
#      '476483',
#      '4768459',
#      '4777087',
#      '4792772',
#      '4796082',
#      '4799088',
#      '4803046',
#      '4803512',
#      '4803525',
#      '4803527',
#      '4803528',
#      '481116',
#      '4816761',
#      '4833691',
#      '4838252',
#      '4842543',
#      '485866',
#      '4859357',
#      '4860542',
#      '489096',
#      '4893896',
#      '4907164',
#      '4908104',
#      '491132',
#      '4925777',
#      '4939767',
#      '4950482',
#      '495365',
#      '4966582',
#      '497881',
#      '498104',
#      '4982682',
#      '49873',
#      '4989285',
#      '499500',
#      '4996218',
#      '500935',
#      '5017860',
#      '502489',
#      '50253',
#      '5030592',
#      '5049',
#      '504900',
#      '505433',
#      '5055131',
#      '505667',
#      '5067406',
#      '507276',
#      '5080040',
#      '51045',
#      '510836',
#      '511967',
#      '512905',
#      '514683',
#      '5147743',
#      '5152867',
#      '5163590',
#      '5171759',
#      '51722',
#      '5230141',
#      '5231023',
#      '527721',
#      '527986',
#      '5284314',
#      '5306593',
#      '5310225',
#      '5316523',
#      '5317567',
#      '5332318',
#      '5332362',
#      '5332426',
#      '5332455',
#      '5332472',
#      '533465',
#      '5338529',
#      '5340034',
#      '5340880',
#      '534149',
#      '5350151',
#      '535043',
#      '5357015',
#      '5357185',
#      '5363463',
#      '5380436',
#      '5380652',
#      '5397234',
#      '540071',
#      '5431108',
#      '5432507',
#      '5436693',
#      '544675',
#      '545191',
#      '5459943',
#      '5460325',
#      '5461695',
#      '5467201',
#      '546735',
#      '5488015',
#      '5501955',
#      '5502068',
#      '5509234',
#      '5547348',
#      '5548062',
#      '555014',
#      '5553',
#      '5560958',
#      '5569497',
#      '5577080',
#      '559441',
#      '560814',
#      '5628989',
#      '56597',
#      '567034',
#      '5680771',
#      '5712577',
#      '5715',
#      '5767812',
#      '576924',
#      '577816',
#      '5784693',
#      '5785843',
#      '579421',
#      '580542',
#      '580978',
#      '581277',
#      '582611',
#      '5837874',
#      '584529',
#      '584612',
#      '586175',
#      '5888135',
#      '5891',
#      '591478',
#      '5951885',
#      '596047',
#      '596114',
#      '597625',
#      '598053',
#      '6001675',
#      '602634',
#      '6028905',
#      '603131',
#      '605538',
#      '6058083',
#      '6062216',
#      '6085327',
#      '6087',
#      '6088120',
#      '6116235',
#      '6116532',
#      '6144608',
#      '6158108',
#      '6161085',
#      '6166199',
#      '616774',
#      '6170763',
#      '6186385',
#      '619810',
#      '621236',
#      '621514',
#      '6224100',
#      '623011',
#      '623038',
#      '623250',
#      '6233814',
#      '624020',
#      '624466',
#      '6249321',
#      '6272023',
#      '6274540',
#      '6275750',
#      '62871',
#      '6289433',
#      '63107',
#      '631128',
#      '6315619',
#      '632124',
#      '632378',
#      '6326',
#      '633634',
#      '633676',
#      '633736',
#      '633935',
#      '6351705',
#      '635876',
#      '6370492',
#      '63998',
#      '6415656',
#      '641843',
#      '6426976',
#      '6435863',
#      '6445367',
#      '6455182',
#      '6464148',
#      '6464150',
#      '6464157',
#      '647416',
#      '648195',
#      '649394',
#      '649572',
#      '651869',
#      '65419',
#      '654519',
#      '66160',
#      '66240',
#      '665748',
#      '666048',
#      '670867',
#      '672536',
#      '67507',
#      '675955',
#      '676496',
#      '6779',
#      '67837',
#      '67862',
#      '680736',
#      '683648',
#      '684750',
#      '68661',
#      '68934',
#      '68982',
#      '69102',
#      '691314',
#      '694159',
#      '694175',
#      '697073',
#      '697239',
#      '700748',
#      '7010',
#      '701297',
#      '70952',
#      '711135',
#      '711265',
#      '715800',
#      '717089',
#      '718923',
#      '720609',
#      '7213',
#      '722053',
#      '75424',
#      '755587',
#      '767930',
#      '775666',
#      '811230',
#      '814655',
#      '82259',
#      '83411',
#      '83557',
#      '84069',
#      '857408',
#      '8703',
#      '870861',
#      '872239',
#      '872831',
#      '87483',
#      '877337',
#      '880537',
#      '88347',
#      '888376',
#      '90243',
#      '911575',
#      '91490',
#      '9176',
#      '934828',
#      '94578',
#      '94660',
#      '960774',
#      '967832',
#      '975150',
#      '977652',
#      '986078',
#      '986138',
#      '986232',
#      '986482',
#      '986634',
#      '986643',
#      '989747',
#      '99810'])

# %%
# 更改地图中名字是英文的问题，替换为中文

# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

a = u'\u5b81\u6ce2\u5e02\u5987\u5973\u513f\u7ae5\u533b\u9662'
b = u'\u4e0a\u6d77\u5e02\u4e16\u754c\u5916\u56fd\u8bed\u4e2d\u5b66'
c = u'\u4e2d\u56fd\u5efa\u8bbe\u94f6\u884c'
d = u'\u661f\u5df4\u514b'
OSMFILE = "shanghai4.osm"
name_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
expected = ["a", "b"]

mapping = { "Ningbo Women & Children Hospital": "a",
            "World Foreign Language Middle School":"b",
           "China Construction Bank":"c",
           "Starbucks":"d"
            }

def audit_name_type(name_types, tag_name):
    m = name_type_re.search(tag_name)
    if m:
        name_type = m.group()
        if name_type not in expected:
            name_types[name_type].add(tag_name)


def is_tag_name(elem):
    return (elem.attrib['k'] == "name")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    name_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_tag_name(tag):
                    audit_name_type(name_types, tag.attrib['v'])
    osm_file.close()
    return name_types


def update_name(name, mapping):
    changeword=mapping.keys()
    for word in mapping:
        if name(word): 
            return name.replace(word, mapping[word])

        
def test():
    n_types = audit(OSMFILE)
    pprint.pprint(dict(n_types))
    for n_type, ways in n_types.iteritems():
        for name in ways:
            better = update_name
            print name, "=>", better
            


if __name__ =='__main__':
    test()
# Out:
# {u'03\u7701\u9053': set([u'03\u7701\u9053']),
#  u'04\u680b': set([u'04\u680b']),
#  u'1#\u6559\u5b66\u697c\uff08\u5de5\u5546\u5b66\u9662\uff09': set([u'1#\u6559\u5b66\u697c\uff08\u5de5\u5546\u5b66\u9662\uff09']),
#  '1(1)': set(['1(1)']),
#  '10': set(['10']),
#  u'104\u56fd\u9053': set([u'104\u56fd\u9053']),
#  '107': set(['107']),
#  u'10\u533a': set([u'\u7d2b\u7af9\u82d110\u533a']),
#  u'11': set([u'\u672c\u79d1\u751f\u516c\u5bd311']),
#  u'11#\u5b66\u751f\u5bbf\u820d': set([u'11#\u5b66\u751f\u5bbf\u820d']),
#  u'1168\u5f047\u652f\u5f04': set([u'1168\u5f047\u652f\u5f04']),
#  '1188': set(['Am Tor des Compounds Jia Hua Riviera auf der Puming Rd. 1188']),
#  '12': set(['12']),
#  u'12-14\u53f7\u697c': set([u'12-14\u53f7\u697c']),
#  '123': set(['123']),
#  '13': set(['13']),
#  u'13\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u6587\u91ce\u5df713\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  u'13\u680b': set([u'\u9999\u6a1f\u56ed13\u680b']),
#  '14': set(['14']),
#  u'149\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u897f\u6eaa\u8def149\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '16': set(['16']),
#  '17': set(['17']),
#  '18': set(['18']),
#  u'18\u53f7': set([u'\u5916\u6ee918\u53f7']),
#  u'1\u53f7\u7ebf': set([u'\u4e0a\u6d77\u8f68\u9053\u4ea4\u901a1\u53f7\u7ebf']),
#  u'1\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u5927\u519c\u6e2f\u8def\u60e0\u5170\u96c5\u8def\u53e31\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '2': set(['2', 'Korean #2']),
#  '20': set(['20']),
#  '213': set(['Provincial Road 213']),
#  '214': set(['Provincial Road #214']),
#  '22': set(['22']),
#  u'220kV\u53d8\u7535\u7ad9': set([u'\u4e0a\u6d77\u7535\u529b\u516c\u53f8\u5927\u5b66220kV\u53d8\u7535\u7ad9']),
#  u'248\u5f04': set([u'\u961c\u65b0\u8def248\u5f04']),
#  u'24\u533a': set([u'\u68d5\u6988\u82d124\u533a']),
#  '25': set(['25']),
#  '26': set(['26']),
#  '27': set(['27']),
#  u'2\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u4e5d\u534e\u8def2\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '3': set(['3']),
#  u'30\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u4ed3\u6cb3\u4e0b30\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '31': set(['31']),
#  u'320\u5f04\u5185': set([u'\u82b3\u82af\u8def320\u5f04\u5185']),
#  u'329\u56fd\u9053': set([u'329\u56fd\u9053']),
#  u'32\u5e62': set([u'32\u5e62']),
#  u'353\u5e7f\u573a': set([u'353\u5e7f\u573a']),
#  u'358\u5f04': set([u'\u9e64\u5e86\u8def358\u5f04']),
#  u'3\u5e62': set([u'\u54cd\u6c34\u575d\u5f043\u5e62']),
#  '4': set(['4']),
#  '40': set(['40']),
#  '41': set(['41']),
#  '44': set(['44']),
#  '49': set(['49']),
#  u'4\u6559\u5b66\u697c': set([u'\u897f4\u6559\u5b66\u697c']),
#  u'500KV\u8d85\u9ad8\u538b\u53d8\u7535\u7ad9': set([u'\u91cc\u6728\u6805500KV\u8d85\u9ad8\u538b\u53d8\u7535\u7ad9']),
#  '54': set(['54']),
#  u'55\u5e62': set([u'55\u5e62']),
#  '58': set(['58']),
#  '59': set(['59']),
#  '59-60': set(['59-60']),
#  u'59\u8def\u516c\u4ea4\u7ec8\u70b9\u7ad9\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u91c7\u8377\u8def59\u8def\u516c\u4ea4\u7ec8\u70b9\u7ad9\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '6': set(['6']),
#  u'60\u53f7\u5c0f\u533a': set([u'\u9ec4\u5929\u8361\u8def60\u53f7\u5c0f\u533a']),
#  u'62-63\u53f7': set([u'62-63\u53f7']),
#  '64': set(['64']),
#  '67': set(['67']),
#  '68': set(['68']),
#  '7': set(['7']),
#  u'7\u5e62': set([u'7\u5e62']),
#  '8': set(['8']),
#  u'852\u5f04': set([u'\u5de8\u9e7f\u8def852\u5f04']),
#  u'85\xb0\u9762\u5305\u623f': set([u'85\xb0\u9762\u5305\u623f']),
#  u'8\u53f7\u7ebf': set([u'\u4e0a\u6d77\u8f68\u9053\u4ea4\u901a8\u53f7\u7ebf']),
#  '9': set(['9']),
#  '9-2': set(['9-2']),
#  u'90\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9': set([u'\u5e86\u6625\u8def90\u53f7\u81ea\u884c\u8f66\u79df\u8d41\u70b9']),
#  '94': set(['94']),
#  'A': set(['A']),
#  'Arran': set(['Arran']),
#  u'A\u5ea7': set([u'\u5c0f\u5267\u573aA\u5ea7']),
#  u'Bank': set(['China Construction Bank',
#                'China Merchants Bank',
#                u'\u676d\u5dde\u8054\u5408\u94f6\u884c Hangzhou United Bank']),
#  'Beilu': set(['Huazhen Beilu', 'Qianhe Beilu']),
#  'Building': set(['Deutsche Schule Shanghai Pudong Main Building']),
#  u'Busterminal': set([u'\u5468\u5e84\u6c7d\u8f66\u7ad9 Zhouzhuang Busterminal']),
#  'Centre': set(['Shanghai Marriott City Centre']),
#  'Changxing': set(['ZPMC Changxing']),
#  'Club': set(['Modu Club']),
#  'Dumplings': set(["Yang's Dumplings"]),
#  'Elephante': set(['Elephante']),
#  u'Expressway': set([u'\u6c5f\u5357\u516c\u8def Jiangnan Expressway']),
#  u'Fantasyland': set([u'\u68a6\u5e7b\u4e16\u754c Fantasyland']),
#  'Forest': set(['Bamboo Forest']),
#  'G104': set(['G104']),
#  u'G15W\u5e38\u53f0\u9ad8\u901f': set([u'G15W\u5e38\u53f0\u9ad8\u901f']),
#  'G318': set(['G318']),
#  'G329': set(['G329']),
#  'Garden)': set(['Zunyuan (Jewel  Garden)']),
#  'Gate)': set(['Oriental International Plaza (South Gate)']),
#  u'G\u0101os\xf9': set([u'\u7ed5\u57ce\u9ad8\u901f R\xe0och\xe9ng G\u0101os\xf9']),
#  'Hospital': set(['Ningbo Women & Children Hospital']),
#  'Hotel': set(['Hong Ye Hotel']),
#  u'Icaf\xe9': set([u'Icaf\xe9']),
#  'Inc.': set(['Century 3 (Shanghai) Inc.']),
#  'Jie': set(['Liuting Jie']),
#  u'KFC(\u4e1c\u95e8\u5e97)': set([u'KFC(\u4e1c\u95e8\u5e97)']),
#  'Kunshan': set(['Ramada Kunshan']),
#  u'L2': set([u'\u8574\u704f\u9ad8\u5c14\u592b\u4e3b\u9898\u9910\u5385L2']),
#  'Lacoste': set(['Lacoste']),
#  'Lawsons': set(['Lawsons']),
#  'Lilingkeng': set(['Lilingkeng']),
#  'Line': set(['Zhongheng Line', u'\u5fb7\u6850\u7ebf d\xe9t\xf3ng Line']),
#  'Lu': set(['Anshan Lu', 'Taiyu Lu', 'Xingning Lu', 'Xingzhen Lu']),
#  'Mall': set(['Super Brand Mall']),
#  'Market': set(['Computer Market']),
#  u'Market\uff09': set([u'\u5723\u548c\u5723\u97e9\u56fd\u9986\uff08Korean Fashion Market\uff09']),
#  u'PLAZA': set([u'\u664b\u540888 PLAZA']),
#  'Pattys': set(['Pattys']),
#  'Reel': set(['Reel']),
#  'Relations': set(['Guest Relations']),
#  'Restaurant': set(['Xin Yuan Lou Shanghai Restaurant', 'Ye Shan Restaurant']),
#  'Road': set(['S-Ring Road',
#               'Shounan East Road',
#               'South Tianyaoqiao Road',
#               'TongTu Road',
#               u'\u4e2d\u5174\u8def Zhongxing Road',
#               u'\u6c5f\u4e1c\u5317\u8def - Jiangdong North Road']),
#  u'S223\u91d1\u6865\u8def\u53e3': set([u'S223\u91d1\u6865\u8def\u53e3']),
#  u'S225\u594b\u8fdb\u8def\u53e3': set([u'S225\u594b\u8fdb\u8def\u53e3']),
#  'S229': set(['S229']),
#  'Sinopec': set(['Sinopec']),
#  'South': set(['West Ring Road South']),
#  'Starbucks': set(['Starbucks']),
#  'Store': set(['Bright Store', 'Deshengtang Drug Store']),
#  'Street': set(['Cuisine Street', 'Zhengfa Street']),
#  'Subway': set(['Subway']),
#  u'T2\u7ebf': set([u'T2\u7ebf']),
#  'TeleNav': set(['TeleNav']),
#  'Turbine': set(['Wind Turbine']),
#  u'X308\u53bf\u9053(\u73ca\u745a-\u4e03\u5729)': set([u'\u6cf0\u5174X308\u53bf\u9053(\u73ca\u745a-\u4e03\u5729)']),
#  u'center': set([u'\u91d1\u9e70\u5965\u83b1\u57ce JinYin Outlets shopping center']),
#  'club': set(['yacht club']),
#  'fruit': set(['Fresh fruit']),
#  'gatherer': set(['hunter gatherer']),
#  'park': set(['Haowang park']),
#  'temple': set(['temple']),
#  u'xi\xe0n)': set([u'\u6e56\u76d0\u7ebf (H\xfay\xe1n xi\xe0n)'])}
# Provincial Road #214 => <function update_name at 0x1123a6938>
# Liuting Jie => <function update_name at 0x1123a6938>
# S229 => <function update_name at 0x1123a6938>
# Provincial Road 213 => <function update_name at 0x1123a6938>
# Lawsons => <function update_name at 0x1123a6938>
# 采荷路59路公交终点站自行车租赁点 => <function update_name at 0x1123a6938>
# S223金桥路口 => <function update_name at 0x1123a6938>
# 巨鹿路852弄 => <function update_name at 0x1123a6938>
# 25 => <function update_name at 0x1123a6938>
# 26 => <function update_name at 0x1123a6938>
# 27 => <function update_name at 0x1123a6938>
# 20 => <function update_name at 0x1123a6938>
# 22 => <function update_name at 0x1123a6938>
# 香樟园13栋 => <function update_name at 0x1123a6938>
# 12-14号楼 => <function update_name at 0x1123a6938>
# Shounan East Road => <function update_name at 0x1123a6938>
# TongTu Road => <function update_name at 0x1123a6938>
# 中兴路 Zhongxing Road => <function update_name at 0x1123a6938>
# S-Ring Road => <function update_name at 0x1123a6938>
# South Tianyaoqiao Road => <function update_name at 0x1123a6938>
# 江东北路 - Jiangdong North Road => <function update_name at 0x1123a6938>
# 8 => <function update_name at 0x1123a6938>
# Deutsche Schule Shanghai Pudong Main Building => <function update_name at 0x1123a6938>
# TeleNav => <function update_name at 0x1123a6938>
# Xin Yuan Lou Shanghai Restaurant => <function update_name at 0x1123a6938>
# Ye Shan Restaurant => <function update_name at 0x1123a6938>
# 上海轨道交通1号线 => <function update_name at 0x1123a6938>
# 9-2 => <function update_name at 0x1123a6938>
# 17 => <function update_name at 0x1123a6938>
# T2线 => <function update_name at 0x1123a6938>
# 59 => <function update_name at 0x1123a6938>
# G15W常台高速 => <function update_name at 0x1123a6938>
# 1168弄7支弄 => <function update_name at 0x1123a6938>
# 周庄汽车站 Zhouzhuang Busterminal => <function update_name at 0x1123a6938>
# Century 3 (Shanghai) Inc. => <function update_name at 0x1123a6938>
# 58 => <function update_name at 0x1123a6938>
# 54 => <function update_name at 0x1123a6938>
# Elephante => <function update_name at 0x1123a6938>
# Huazhen Beilu => <function update_name at 0x1123a6938>
# Qianhe Beilu => <function update_name at 0x1123a6938>
# Ningbo Women & Children Hospital => <function update_name at 0x1123a6938>
# 里木栅500KV超高压变电站 => <function update_name at 0x1123a6938>
# 上海电力公司大学220kV变电站 => <function update_name at 0x1123a6938>
# 4 => <function update_name at 0x1123a6938>
# 03省道 => <function update_name at 0x1123a6938>
# 3 => <function update_name at 0x1123a6938>
# 7 => <function update_name at 0x1123a6938>
# 响水坝弄3幢 => <function update_name at 0x1123a6938>
# Zhongheng Line => <function update_name at 0x1123a6938>
# 德桐线 détóng Line => <function update_name at 0x1123a6938>
# Reel => <function update_name at 0x1123a6938>
# temple => <function update_name at 0x1123a6938>
# 仓河下30号自行车租赁点 => <function update_name at 0x1123a6938>
# 晋合88 PLAZA => <function update_name at 0x1123a6938>
# Super Brand Mall => <function update_name at 0x1123a6938>
# Subway => <function update_name at 0x1123a6938>
# hunter gatherer => <function update_name at 0x1123a6938>
# 107 => <function update_name at 0x1123a6938>
# Am Tor des Compounds Jia Hua Riviera auf der Puming Rd. 1188 => <function update_name at 0x1123a6938>
# 04栋 => <function update_name at 0x1123a6938>
# 329国道 => <function update_name at 0x1123a6938>
# 31 => <function update_name at 0x1123a6938>
# Shanghai Marriott City Centre => <function update_name at 0x1123a6938>
# S225奋进路口 => <function update_name at 0x1123a6938>
# 外滩18号 => <function update_name at 0x1123a6938>
# 85°面包房 => <function update_name at 0x1123a6938>
# Wind Turbine => <function update_name at 0x1123a6938>
# G318 => <function update_name at 0x1123a6938>
# Ramada Kunshan => <function update_name at 0x1123a6938>
# Lacoste => <function update_name at 0x1123a6938>
# Guest Relations => <function update_name at 0x1123a6938>
# 64 => <function update_name at 0x1123a6938>
# Bamboo Forest => <function update_name at 0x1123a6938>
# 67 => <function update_name at 0x1123a6938>
# 68 => <function update_name at 0x1123a6938>
# 阜新路248弄 => <function update_name at 0x1123a6938>
# 黄天荡路60号小区 => <function update_name at 0x1123a6938>
# Bright Store => <function update_name at 0x1123a6938>
# Deshengtang Drug Store => <function update_name at 0x1123a6938>
# 绕城高速 Ràochéng Gāosù => <function update_name at 0x1123a6938>
# G104 => <function update_name at 0x1123a6938>
# 小剧场A座 => <function update_name at 0x1123a6938>
# 大农港路惠兰雅路口1自行车租赁点 => <function update_name at 0x1123a6938>
# Hong Ye Hotel => <function update_name at 0x1123a6938>
# 1(1) => <function update_name at 0x1123a6938>
# 353广场 => <function update_name at 0x1123a6938>
# Lilingkeng => <function update_name at 0x1123a6938>
# 2 => <function update_name at 0x1123a6938>
# Korean #2 => <function update_name at 0x1123a6938>
# 6 => <function update_name at 0x1123a6938>
# 湖盐线 (Húyán xiàn) => <function update_name at 0x1123a6938>
# 55幢 => <function update_name at 0x1123a6938>
# Starbucks => <function update_name at 0x1123a6938>
# 文野巷13号自行车租赁点 => <function update_name at 0x1123a6938>
# 芳芯路320弄内 => <function update_name at 0x1123a6938>
# yacht club => <function update_name at 0x1123a6938>
# Haowang park => <function update_name at 0x1123a6938>
# 庆春路90号自行车租赁点 => <function update_name at 0x1123a6938>
# ZPMC Changxing => <function update_name at 0x1123a6938>
# 94 => <function update_name at 0x1123a6938>
# 1#教学楼（工商学院） => <function update_name at 0x1123a6938>
# 本科生公寓11 => <function update_name at 0x1123a6938>
# 上海轨道交通8号线 => <function update_name at 0x1123a6938>
# 13 => <function update_name at 0x1123a6938>
# 12 => <function update_name at 0x1123a6938>
# 九华路2自行车租赁点 => <function update_name at 0x1123a6938>
# 14 => <function update_name at 0x1123a6938>
# 圣和圣韩国馆（Korean Fashion Market） => <function update_name at 0x1123a6938>
# 16 => <function update_name at 0x1123a6938>
# Yang's Dumplings => <function update_name at 0x1123a6938>
# 18 => <function update_name at 0x1123a6938>
# KFC(东门店) => <function update_name at 0x1123a6938>
# Pattys => <function update_name at 0x1123a6938>
# G329 => <function update_name at 0x1123a6938>
# Computer Market => <function update_name at 0x1123a6938>
# 西4教学楼 => <function update_name at 0x1123a6938>
# 7幢 => <function update_name at 0x1123a6938>
# Zunyuan (Jewel  Garden) => <function update_name at 0x1123a6938>
# Xingzhen Lu => <function update_name at 0x1123a6938>
# Anshan Lu => <function update_name at 0x1123a6938>
# Xingning Lu => <function update_name at 0x1123a6938>
# Taiyu Lu => <function update_name at 0x1123a6938>
# Icafé => <function update_name at 0x1123a6938>
# Sinopec => <function update_name at 0x1123a6938>
# 123 => <function update_name at 0x1123a6938>
# 江南公路 Jiangnan Expressway => <function update_name at 0x1123a6938>
# 49 => <function update_name at 0x1123a6938>
# 104国道 => <function update_name at 0x1123a6938>
# 44 => <function update_name at 0x1123a6938>
# 40 => <function update_name at 0x1123a6938>
# 41 => <function update_name at 0x1123a6938>
# 9 => <function update_name at 0x1123a6938>
# 59-60 => <function update_name at 0x1123a6938>
# Oriental International Plaza (South Gate) => <function update_name at 0x1123a6938>
# China Merchants Bank => <function update_name at 0x1123a6938>
# 杭州联合银行 Hangzhou United Bank => <function update_name at 0x1123a6938>
# China Construction Bank => <function update_name at 0x1123a6938>
# 10 => <function update_name at 0x1123a6938>
# A => <function update_name at 0x1123a6938>
# 62-63号 => <function update_name at 0x1123a6938>
# 梦幻世界 Fantasyland => <function update_name at 0x1123a6938>
# 11#学生宿舍 => <function update_name at 0x1123a6938>
# 紫竹苑10区 => <function update_name at 0x1123a6938>
# Fresh fruit => <function update_name at 0x1123a6938>
# 蕴灏高尔夫主题餐厅L2 => <function update_name at 0x1123a6938>
# 泰兴X308县道(珊瑚-七圩) => <function update_name at 0x1123a6938>
# West Ring Road South => <function update_name at 0x1123a6938>
# 棕榈苑24区 => <function update_name at 0x1123a6938>
# 32幢 => <function update_name at 0x1123a6938>
# 西溪路149号自行车租赁点 => <function update_name at 0x1123a6938>
# 金鹰奥莱城 JinYin Outlets shopping center => <function update_name at 0x1123a6938>
# Arran => <function update_name at 0x1123a6938>
# Modu Club => <function update_name at 0x1123a6938>
# Cuisine Street => <function update_name at 0x1123a6938>
# Zhengfa Street => <function update_name at 0x1123a6938>
# 鹤庆路358弄 => <function update_name at 0x1123a6938>

# %%
# 修正文中部分有问题的拼音

# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint
OSMFILE = "shanghai4.osm"
name_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
a = u'liǎng àn kā fēi'
b = u'yín zhōu qū'
c = u'xīn qiáo zhèn'
d = u'dōng bà zhèn'
expected = ["a", "b","c","d"]

mapping = { "Liang'an Kafei": "a",
            "Yinzhou Qu":"b",
           "Xinqiao Zhen":"c",
           "Dongba Zhen":"d"
            }

def audit_name_type(name_types, tag_name):
    m = name_type_re.search(tag_name)
    if m:
        name_type = m.group()
        if name_type not in expected:
            name_types[name_type].add(tag_name)

def is_tag_name(elem):
    return (elem.attrib['k'] == "name:zh_pinyin")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    name_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_tag_name(tag):
                    audit_name_type(name_types, tag.attrib['v'])
    osm_file.close()
    return name_types

def update_name(name, mapping):
    changeword=mapping.keys()
    for word in mapping:
        if name(word): 
            return name.replace(word, mapping[word])
def test():
    n_types = audit(OSMFILE)
    pprint.pprint(dict(n_types))
    
    for n_type, ways in n_types.iteritems():
        for name in ways:
            better = update_name1
            print name, "=>", better
            


if __name__ == '__main__':
    test()
# Out:
# {u'D\xe0d\xe0o': set([u'Li\u01cengg\u01ceng D\xe0d\xe0o',
#                       u'L\xf3ngd\u014dng D\xe0d\xe0o']),
#  u'G\u0101oji\xe0l\xf9': set([u'Lu\xf3sh\u0101n G\u0101oji\xe0l\xf9']),
#  u'G\u0101os\xf9': set([u'H\xe1ngch\xe1ng G\u0101os\xf9',
#                         u'H\xf9h\xe1ng G\u0101os\xf9',
#                         u'H\xf9h\xe1ngy\u01d2ng G\u0101os\xf9',
#                         u'R\xe0och\xe9ng G\u0101os\xf9']),
#  u'G\u014dngl\xf9': set([u'Chu\u0101nb\u011bi G\u014dngl\xf9',
#                          u'J\u016bnm\xedn G\u014dngl\xf9']),
#  u'Ji\u0113': set([u'B\u011bish\u0101n Ji\u0113']),
#  'Kafei': set(["Liang'an Kafei"]),
#  'Lu': set(['Tanghuang Lu']),
#  u'L\xf2ng': set([u'J\u016bnm\xednl\xf9 232 L\xf2ng',
#                   u'Zh\u0113nd\xe0l\xf9 1 L\xf2ng']),
#  u'L\xf9': set([u'B\u01ceosh\xed Y\u012b L\xf9',
#                 u'Ch\xe9nhu\u012b L\xf9',
#                 u'D\xe9sh\xe8ng L\xf9',
#                 u'F\u0101ngch\u016bn L\xf9',
#                 u'Hu\xe1nk\u0113 L\xf9',
#                 u'Hu\xe1y\xec L\xf9',
#                 u'H\xe1ngh\u01cei L\xf9',
#                 u'H\xe9ngmi\u01cenji\u0101ng L\xf9',
#                 u'H\xf3ngy\u012bn L\xf9',
#                 u'H\xfash\xf9 N\xe1n L\xf9',
#                 u'J\u012bnk\u0113 L\xf9',
#                 u'K\u0113yu\xe0n L\xf9',
#                 u'Li\xfaxi\xe1ng L\xf9',
#                 u'Qi\u016bt\u0101o L\xf9',
#                 u'Q\xednzh\xe8ng L\xf9',
#                 u'R\xe9nm\xedn L\xf9',
#                 u'T\u01d0y\xf9ch\u01ceng L\xf9',
#                 u'W\xe9nc\u01cei L\xf9',
#                 u'W\xe9ny\u012b X\u012b L\xf9',
#                 u'Y\xf9y\u01d4 L\xf9',
#                 u'Zh\u012bji\u0101ng L\xf9',
#                 u'Zh\u014dnghu\xe1n L\xf9']),
#  'Qu': set(['Yinzhou Qu']),
#  u'Sh\xedhu\xe0': set([u'Zh\u014dnggu\xf3 Sh\xedhu\xe0']),
#  u'S\u014dngm\xf9ch\xe1ngh\xe9d\u014dng': set([u'S\u014dngm\xf9ch\xe1ngh\xe9d\u014dng']),
#  u'X\u012bl\xf9': set([u'Y\xfanl\u01d0ng X\u012bl\xf9']),
#  u'X\u012bnyu\xe1nl\xf9': set([u'X\u012bnyu\xe1nl\xf9']),
#  u'Y\xednh\xe1ng': set([u'H\xe1ngzh\u014du Li\xe1nh\xe9 Y\xednh\xe1ng',
#                         u'Zh\u0101osh\u0101ng Y\xednh\xe1ng']),
#  'Zhen': set(['Dongba Zhen', 'Xinqiao Zhen']),
#  u'Z\xe9p\u01d4l\xf9': set([u'Z\xe9p\u01d4l\xf9']),
#  u'ji\u0101ng': set([u'p\u016dy\xe1ng ji\u0101ng']),
#  u'xi\xe0n': set([u'H\xfay\xe1n xi\xe0n']),
#  u'yu\xe0n': set([u'j\xecng \u0101n h\xe1o j\u01d0ng yu\xe0n']),
#  u'y\xf9nh\xe9': set([u't\u014dngy\xe1ng y\xf9nh\xe9'])}
# Hùháng Gāosù => <function update_name1 at 0x1123a6b18>
# Hángcháng Gāosù => <function update_name1 at 0x1123a6b18>
# Ràochéng Gāosù => <function update_name1 at 0x1123a6b18>
# Hùhángyǒng Gāosù => <function update_name1 at 0x1123a6b18>
# Húyán xiàn => <function update_name1 at 0x1123a6b18>
# Yinzhou Qu => <function update_name1 at 0x1123a6b18>
# Luóshān Gāojiàlù => <function update_name1 at 0x1123a6b18>
# Jūnmín Gōnglù => <function update_name1 at 0x1123a6b18>
# Chuānběi Gōnglù => <function update_name1 at 0x1123a6b18>
# Jūnmínlù 232 Lòng => <function update_name1 at 0x1123a6b18>
# Zhēndàlù 1 Lòng => <function update_name1 at 0x1123a6b18>
# Zépǔlù => <function update_name1 at 0x1123a6b18>
# Liang'an Kafei => <function update_name1 at 0x1123a6b18>
# Liǎnggǎng Dàdào => <function update_name1 at 0x1123a6b18>
# Lóngdōng Dàdào => <function update_name1 at 0x1123a6b18>
# tōngyáng yùnhé => <function update_name1 at 0x1123a6b18>
# Zhōngguó Shíhuà => <function update_name1 at 0x1123a6b18>
# Yúnlǐng Xīlù => <function update_name1 at 0x1123a6b18>
# Zhāoshāng Yínháng => <function update_name1 at 0x1123a6b18>
# Hángzhōu Liánhé Yínháng => <function update_name1 at 0x1123a6b18>
# jìng ān háo jǐng yuàn => <function update_name1 at 0x1123a6b18>
# Běishān Jiē => <function update_name1 at 0x1123a6b18>
# Sōngmùchánghédōng => <function update_name1 at 0x1123a6b18>
# pŭyáng jiāng => <function update_name1 at 0x1123a6b18>
# Xinqiao Zhen => <function update_name1 at 0x1123a6b18>
# Dongba Zhen => <function update_name1 at 0x1123a6b18>
# Xīnyuánlù => <function update_name1 at 0x1123a6b18>
# Tanghuang Lu => <function update_name1 at 0x1123a6b18>
# Zhōnghuán Lù => <function update_name1 at 0x1123a6b18>
# Déshèng Lù => <function update_name1 at 0x1123a6b18>
# Qínzhèng Lù => <function update_name1 at 0x1123a6b18>
# Jīnkē Lù => <function update_name1 at 0x1123a6b18>
# Bǎoshí Yī Lù => <function update_name1 at 0x1123a6b18>
# Hánghǎi Lù => <function update_name1 at 0x1123a6b18>
# Húshù Nán Lù => <function update_name1 at 0x1123a6b18>
# Tǐyùchǎng Lù => <function update_name1 at 0x1123a6b18>
# Huánkē Lù => <function update_name1 at 0x1123a6b18>
# Rénmín Lù => <function update_name1 at 0x1123a6b18>
# Héngmiǎnjiāng Lù => <function update_name1 at 0x1123a6b18>
# Zhījiāng Lù => <function update_name1 at 0x1123a6b18>
# Huáyì Lù => <function update_name1 at 0x1123a6b18>
# Hóngyīn Lù => <function update_name1 at 0x1123a6b18>
# Qiūtāo Lù => <function update_name1 at 0x1123a6b18>
# Yùyǔ Lù => <function update_name1 at 0x1123a6b18>
# Fāngchūn Lù => <function update_name1 at 0x1123a6b18>
# Liúxiáng Lù => <function update_name1 at 0x1123a6b18>
# Chénhuī Lù => <function update_name1 at 0x1123a6b18>
# Wényī Xī Lù => <function update_name1 at 0x1123a6b18>
# Wéncǎi Lù => <function update_name1 at 0x1123a6b18>
# Kēyuàn Lù => <function update_name1 at 0x1123a6b18>

# %%
# 导出为csv格式

import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema1

OSM_PATH = "shanghai4.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema1.schema




NODE_FIELDS = ['changeset','id', 'lat', 'lon','timestamp', 'uid','user','version']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['changeset','id','timestamp','uid','user', 'version']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']



def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
def shape_tag(el, tag): 
    tag = {
        'id'   : el.attrib['id'],
        'key'  : tag.attrib['k'],
        'value': tag.attrib['v'],
        'type' : 'regular'
    }
    
    if LOWER_COLON.match(tag['key']):
        tag['type'], _, tag['key'] = tag['key'].partition(':')
        
    return tag
    
def shape_way_node(el, i, nd):
    return {
        'id'       : el.attrib['id'],
        'node_id'  : nd.attrib['ref'],
        'position' : i
    }


def shape_element(el, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS):
                      
    tags = [shape_tag(el, t) for t in el.iter('tag')]

    if el.tag == 'node':
        node_attribs = {f: el.attrib[f] for f in node_attr_fields}
        
        return {'node': node_attribs, 'node_tags': tags}
        
    elif el.tag == 'way':
        way_attribs = {f: el.attrib[f] for f in way_attr_fields}
        
        way_nodes = [shape_way_node(el, i, nd) 
                     for i, nd 
                     in enumerate(el.iter('nd'))]
   
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

    



# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
